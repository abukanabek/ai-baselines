# %%
# https://platform.olimpiada-ai.ro/problems/30

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %%
train = pd.read_csv("/kaggle/input/text-based-emotion-classification/train.csv")
test = pd.read_csv("/kaggle/input/text-based-emotion-classification/test.csv")

# %%
class2idx = {
    'sadness': 0,
    'anger': 1,
    'love': 2,
    'surprise': 3,
    'fear': 4,
    'joy': 5
}

idx2class = {v: k for k, v in class2idx.items()}

train['label'] = train['label'].map(class2idx.get)

# %%
from sklearn.model_selection import train_test_split
from catboost import Pool

features = ['text']
text_features = ['text']

X, y = train[features], train['label']
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=42, test_size=0.1, stratify=y)

train_pool = Pool(X_train, y_train, text_features=text_features)
valid_pool = Pool(X_valid, y_valid, text_features=text_features)

# %%
from catboost import CatBoostClassifier

params = {
    'iterations': 1000,
    'loss_function': 'MultiClass',
    'eval_metric': 'TotalF1:average=Macro',
    'metric_period': 25,
    'max_depth': 4
}

model = CatBoostClassifier(**params)

model.fit(train_pool, eval_set=valid_pool)
# Out:
# Learning rate set to 0.113892
# 0:	learn: 0.5474287	test: 0.6133631	best: 0.6133631 (0)	total: 231ms	remaining: 3m 50s
# 25:	learn: 0.6387257	test: 0.6879484	best: 0.6879484 (25)	total: 6.26s	remaining: 3m 54s
# 50:	learn: 0.6840588	test: 0.7250471	best: 0.7250471 (50)	total: 11.9s	remaining: 3m 40s
# 75:	learn: 0.6989875	test: 0.7377022	best: 0.7377022 (75)	total: 17.4s	remaining: 3m 31s
# 100:	learn: 0.7126844	test: 0.7508305	best: 0.7508305 (100)	total: 22.7s	remaining: 3m 21s
# 125:	learn: 0.7186493	test: 0.7620243	best: 0.7620243 (125)	total: 28.2s	remaining: 3m 15s
# 150:	learn: 0.7239404	test: 0.7725448	best: 0.7725448 (150)	total: 33.6s	remaining: 3m 9s
# 175:	learn: 0.7297793	test: 0.7726728	best: 0.7726728 (175)	total: 39.1s	remaining: 3m 2s
# 200:	learn: 0.7381477	test: 0.7769422	best: 0.7769422 (200)	total: 44.5s	remaining: 2m 56s
# 225:	learn: 0.7413441	test: 0.7770605	best: 0.7770605 (225)	total: 50s	remaining: 2m 51s
# 250:	learn: 0.7470384	test: 0.7743223	best: 0.7770605 (225)	total: 55.6s	remaining: 2m 45s
# 275:	learn: 0.7507307	test: 0.7811957	best: 0.7811957 (275)	total: 1m 1s	remaining: 2m 40s
# 300:	learn: 0.7556140	test: 0.7838190	best: 0.7838190 (300)	total: 1m 6s	remaining: 2m 34s
# 325:	learn: 0.7584938	test: 0.7848961	best: 0.7848961 (325)	total: 1m 12s	remaining: 2m 29s
# 350:	learn: 0.7625015	test: 0.7892875	best: 0.7892875 (350)	total: 1m 17s	remaining: 2m 23s
# 375:	learn: 0.7649487	test: 0.7879204	best: 0.7892875 (350)	total: 1m 23s	remaining: 2m 18s
# 400:	learn: 0.7675007	test: 0.7921885	best: 0.7921885 (400)	total: 1m 28s	remaining: 2m 12s
# 425:	learn: 0.7725275	test: 0.7939006	best: 0.7939006 (425)	total: 1m 34s	remaining: 2m 7s
# 450:	learn: 0.7755511	test: 0.7945942	best: 0.7945942 (450)	total: 1m 39s	remaining: 2m 1s
# 475:	learn: 0.7773525	test: 0.7978084	best: 0.7978084 (475)	total: 1m 45s	remaining: 1m 56s
# 500:	learn: 0.7795082	test: 0.7975706	best: 0.7978084 (475)	total: 1m 51s	remaining: 1m 50s
# 525:	learn: 0.7829453	test: 0.7978849	best: 0.7978849 (525)	total: 1m 56s	remaining: 1m 45s
# 550:	learn: 0.7856621	test: 0.8034786	best: 0.8034786 (550)	total: 2m 2s	remaining: 1m 39s
# 575:	learn: 0.7895538	test: 0.8007130	best: 0.8034786 (550)	total: 2m 7s	remaining: 1m 33s
# 600:	learn: 0.7904639	test: 0.8015666	best: 0.8034786 (550)	total: 2m 13s	remaining: 1m 28s
# 625:	learn: 0.7936462	test: 0.8035171	best: 0.8035171 (625)	total: 2m 18s	remaining: 1m 22s
# 650:	learn: 0.7971711	test: 0.8104990	best: 0.8104990 (650)	total: 2m 24s	remaining: 1m 17s
# 675:	learn: 0.7987680	test: 0.8128061	best: 0.8128061 (675)	total: 2m 29s	remaining: 1m 11s
# 700:	learn: 0.8010564	test: 0.8122674	best: 0.8128061 (675)	total: 2m 35s	remaining: 1m 6s
# 725:	learn: 0.8044229	test: 0.8131075	best: 0.8131075 (725)	total: 2m 41s	remaining: 1m
# 750:	learn: 0.8069839	test: 0.8108197	best: 0.8131075 (725)	total: 2m 46s	remaining: 55.3s
# 775:	learn: 0.8079904	test: 0.8136168	best: 0.8136168 (775)	total: 2m 52s	remaining: 49.8s
# 800:	learn: 0.8114299	test: 0.8174170	best: 0.8174170 (800)	total: 2m 58s	remaining: 44.3s
# 825:	learn: 0.8139334	test: 0.8176294	best: 0.8176294 (825)	total: 3m 3s	remaining: 38.7s
# 850:	learn: 0.8169536	test: 0.8166293	best: 0.8176294 (825)	total: 3m 9s	remaining: 33.2s
# 875:	learn: 0.8186722	test: 0.8174150	best: 0.8176294 (825)	total: 3m 14s	remaining: 27.6s
# 900:	learn: 0.8202552	test: 0.8171207	best: 0.8176294 (825)	total: 3m 20s	remaining: 22s
# 925:	learn: 0.8212904	test: 0.8165332	best: 0.8176294 (825)	total: 3m 25s	remaining: 16.5s
# 950:	learn: 0.8223636	test: 0.8141594	best: 0.8176294 (825)	total: 3m 31s	remaining: 10.9s
# 975:	learn: 0.8253102	test: 0.8168531	best: 0.8176294 (825)	total: 3m 37s	remaining: 5.34s
# 999:	learn: 0.8263409	test: 0.8163558	best: 0.8176294 (825)	total: 3m 42s	remaining: 0us
#
# bestTest = 0.8176293794
# bestIteration = 825
#
# Shrink model to first 826 iterations.

# %%
from sklearn.metrics import f1_score

y_pred = model.predict(X_valid).flatten()

score = f1_score(y_valid, y_pred, average='macro')
print(f"F1 Score: {score:.5f}")
# Out:
# F1 Score: 0.81763

# %%
X_test = test[features]

y_pred = model.predict(X_test).flatten()

subm = pd.DataFrame({
    'SampleID': test['SampleID'],
    'label': list(map(idx2class.get, y_pred))
})

subm
# Out:
#       SampleID    label
# 0        16001  sadness
# 1        16002  sadness
# 2        16003  sadness
# 3        16004      joy
# 4        16005  sadness
# ...        ...      ...
# 1995     17996    anger
# 1996     17997    anger
# 1997     17998      joy
# 1998     17999      joy
# 1999     18000     fear
#
# [2000 rows x 2 columns]

# %%
subm.to_csv("submission.csv", index=False)
