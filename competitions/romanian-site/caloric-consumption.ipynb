# %%
# https://platform.olimpiada-ai.ro/en/problems/74

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("/kaggle/input/caloric-consumption/train_data.csv")
test = pd.read_csv("/kaggle/input/caloric-consumption/test_data.csv")
subm = pd.read_csv("/kaggle/input/caloric-consumption/sample_output.csv")

# train.drop_duplicates(inplace=True)

train.shape, test.shape, subm.shape
# Out:
# ((9000, 9), (2500, 9), (2504, 3))

# %%
subm.loc[:3, 'answer'] = [len(train), (train['Gender'] == 'male').sum().item(), train['Duration'].mean().item(), (train['Age'] >= 75).sum().item()]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     9000 non-null   int64
#  1   Age         9000 non-null   int64
#  2   Height      9000 non-null   int64
#  3   Weight      9000 non-null   int64
#  4   Duration    9000 non-null   int64
#  5   Heart_Rate  9000 non-null   int64
#  6   Body_Temp   9000 non-null   float64
#  7   Gender      9000 non-null   object
#  8   Calories    9000 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 632.9+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subtask     2500 non-null   int64
#  1   User_ID     2500 non-null   int64
#  2   Age         2500 non-null   int64
#  3   Height      2500 non-null   int64
#  4   Weight      2500 non-null   int64
#  5   Duration    2500 non-null   int64
#  6   Heart_Rate  2500 non-null   int64
#  7   Body_Temp   2500 non-null   float64
#  8   Gender      2000 non-null   object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 175.9+ KB

# %%
train.groupby('Gender')['Calories'].agg(['mean', 'median', 'min', 'max'])
# Out:
#              mean  median  min  max
# Gender
# female  88.196621    80.0    2  240
# male    90.699077    77.0    1  314

# %%
subm['subtaskID'].value_counts()
# Out:
# subtaskID
# 5    2000
# 6     500
# 2       1
# 1       1
# 4       1
# 3       1
# Name: count, dtype: int64

# %%
train['Gender_male'] = (train['Gender']=='male').astype(int)
train['Gender_female'] = (train['Gender']=='female').astype(int)
train['Gender_other'] = (~train['Gender'].isin(['male', 'female'])).astype(int)

test['Gender_male'] = (test['Gender']=='male').astype(int)
test['Gender_female'] = (test['Gender']=='female').astype(int)
test['Gender_other'] = (~test['Gender'].isin(['male', 'female'])).astype(int)

train.drop(columns=['Gender'], inplace=True)
test.drop(columns=['Gender'], inplace=True)

# %%
from sklearn.model_selection import train_test_split

features = ['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', "Gender_male", "Gender_female", "Gender_other"]
target_col = 'Calories'

X, y = train[features], train[target_col]
X_test = test[features]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=42, test_size=0.2)

X_train.shape, X_valid.shape
# Out:
# ((7200, 9), (1800, 9))

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

model = GradientBoostingRegressor(random_state=42, loss='absolute_error')

param_grid = {
    'max_depth': [3, 4, 5, 6, 7, 8, 9],
    'n_estimators': [100, 500]
}
search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_absolute_error', refit=True, verbose=2)

search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.9s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.9s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.9s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.9s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.9s
# [CV] END ......................max_depth=3, n_estimators=500; total time=   4.3s
# [CV] END ......................max_depth=3, n_estimators=500; total time=   4.3s
# [CV] END ......................max_depth=3, n_estimators=500; total time=   4.2s
# [CV] END ......................max_depth=3, n_estimators=500; total time=   4.3s
# [CV] END ......................max_depth=3, n_estimators=500; total time=   4.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   1.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   1.3s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   1.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   1.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   1.2s
# [CV] END ......................max_depth=4, n_estimators=500; total time=   5.5s
# [CV] END ......................max_depth=4, n_estimators=500; total time=   5.4s
# [CV] END ......................max_depth=4, n_estimators=500; total time=   5.6s
# [CV] END ......................max_depth=4, n_estimators=500; total time=   5.8s
# [CV] END ......................max_depth=4, n_estimators=500; total time=   5.6s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   1.6s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ......................max_depth=5, n_estimators=500; total time=   6.9s
# [CV] END ......................max_depth=5, n_estimators=500; total time=   6.8s
# [CV] END ......................max_depth=5, n_estimators=500; total time=   6.6s
# [CV] END ......................max_depth=5, n_estimators=500; total time=   6.6s
# [CV] END ......................max_depth=5, n_estimators=500; total time=   6.8s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   2.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   2.4s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   2.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   2.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   2.3s
# [CV] END ......................max_depth=6, n_estimators=500; total time=   8.1s
# [CV] END ......................max_depth=6, n_estimators=500; total time=   8.2s
# [CV] END ......................max_depth=6, n_estimators=500; total time=   8.0s
# [CV] END ......................max_depth=6, n_estimators=500; total time=   8.1s
# [CV] END ......................max_depth=6, n_estimators=500; total time=   8.2s
# [CV] END ......................max_depth=7, n_estimators=100; total time=   3.0s
# [CV] END ......................max_depth=7, n_estimators=100; total time=   3.0s
# [CV] END ......................max_depth=7, n_estimators=100; total time=   3.1s
# [CV] END ......................max_depth=7, n_estimators=100; total time=   3.1s
# [CV] END ......................max_depth=7, n_estimators=100; total time=   3.0s
# [CV] END ......................max_depth=7, n_estimators=500; total time=  10.0s
# [CV] END ......................max_depth=7, n_estimators=500; total time=  10.1s
# [CV] END ......................max_depth=7, n_estimators=500; total time=  10.1s
# [CV] END ......................max_depth=7, n_estimators=500; total time=  11.6s
# [CV] END ......................max_depth=7, n_estimators=500; total time=  12.5s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   5.6s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   6.1s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   6.4s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   6.9s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   4.5s
# [CV] END ......................max_depth=8, n_estimators=500; total time=  12.4s
# [CV] END ......................max_depth=8, n_estimators=500; total time=  13.1s
# [CV] END ......................max_depth=8, n_estimators=500; total time=  19.9s
# [CV] END ......................max_depth=8, n_estimators=500; total time=  14.3s
# [CV] END ......................max_depth=8, n_estimators=500; total time=  12.5s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   5.6s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   5.4s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   5.5s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   5.3s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   5.2s
# [CV] END ......................max_depth=9, n_estimators=500; total time=  18.0s
# [CV] END ......................max_depth=9, n_estimators=500; total time=  14.3s
# [CV] END ......................max_depth=9, n_estimators=500; total time=  14.1s
# [CV] END ......................max_depth=9, n_estimators=500; total time=  13.6s
# [CV] END ......................max_depth=9, n_estimators=500; total time=  14.2s
# GridSearchCV(cv=5,
#              estimator=GradientBoostingRegressor(loss='absolute_error',
#                                                  random_state=42),
#              param_grid={'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                          'n_estimators': [100, 500]},
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
search.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 500}

# %%
from sklearn.metrics import mean_absolute_error

preds = search.predict(X_valid)

mae = mean_absolute_error(y_valid, preds)

print(f'MAE: {mae:.5f}')
# Out:
# MAE: 1.51685

# %%
subm.loc[4:, 'answer'] = search.predict(X_test)
subm.to_csv("submission.csv", index=False)
